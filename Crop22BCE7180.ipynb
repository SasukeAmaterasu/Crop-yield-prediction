# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("crop.csv")

# %%
df
# Out:
#      Rain Fall (mm)  Fertilizer(urea) (kg/acre)  Temperature (°C)  \
# 0       1230.000000                   80.000000         28.000000
# 1        480.000000                   60.000000         36.000000
# 2       1250.000000                   75.000000         29.000000
# 3        450.000000                   65.000000         35.000000
# 4       1200.000000                   80.000000         27.000000
# ..              ...                         ...               ...
# 98      1230.000000                   80.000000         28.000000
# 99       400.000000                   50.000000         24.000000
# 100     1300.000000                   80.000000         40.000000
# 101      849.797980                   67.808081         32.393939
# 102      400.042676                   10.028202          5.426350
#
#      Nitrogen (N)  Phosphorus (P)  Potassium (K)      Yeild  Unnamed: 7
# 0       80.000000       24.000000      20.000000  12.000000         NaN
# 1       70.000000       20.000000      18.000000   8.000000         NaN
# 2       78.000000       22.000000      19.000000  11.000000         NaN
# 3       70.000000       19.000000      18.000000   9.000000         NaN
# 4       79.000000       22.000000      19.000000  11.000000         NaN
# ..            ...             ...            ...        ...         ...
# 98      80.000000       24.000000      20.000000  12.000000         NaN
# 99      59.000000       18.000000      15.000000   5.500000         NaN
# 100     80.000000       25.000000      22.000000  12.000000         NaN
# 101     70.737374       21.131313      18.060606   9.050505         NaN
# 102      6.677079        1.951695       1.817254   1.965902         NaN
#
# [103 rows x 8 columns]

# %%
df = df.drop('Unnamed: 7', axis=1)

# %%
df
# Out:
#      Rain Fall (mm)  Fertilizer(urea) (kg/acre)  Temperature (°C)  \
# 0       1230.000000                   80.000000         28.000000
# 1        480.000000                   60.000000         36.000000
# 2       1250.000000                   75.000000         29.000000
# 3        450.000000                   65.000000         35.000000
# 4       1200.000000                   80.000000         27.000000
# ..              ...                         ...               ...
# 98      1230.000000                   80.000000         28.000000
# 99       400.000000                   50.000000         24.000000
# 100     1300.000000                   80.000000         40.000000
# 101      849.797980                   67.808081         32.393939
# 102      400.042676                   10.028202          5.426350
#
#      Nitrogen (N)  Phosphorus (P)  Potassium (K)      Yeild
# 0       80.000000       24.000000      20.000000  12.000000
# 1       70.000000       20.000000      18.000000   8.000000
# 2       78.000000       22.000000      19.000000  11.000000
# 3       70.000000       19.000000      18.000000   9.000000
# 4       79.000000       22.000000      19.000000  11.000000
# ..            ...             ...            ...        ...
# 98      80.000000       24.000000      20.000000  12.000000
# 99      59.000000       18.000000      15.000000   5.500000
# 100     80.000000       25.000000      22.000000  12.000000
# 101     70.737374       21.131313      18.060606   9.050505
# 102      6.677079        1.951695       1.817254   1.965902
#
# [103 rows x 7 columns]

# %%
import seaborn as sns

# %%
sns.pairplot(df,x_vars=['Rain Fall (mm)','Fertilizer(urea) (kg/acre)','Temperature (°C)','Nitrogen (N)'	,'Phosphorus (P)','Potassium (K)'],y_vars=['Yeild'])

# %%
df.corr
# Out:
# <bound method DataFrame.corr of      Rain Fall (mm)  Fertilizer(urea) (kg/acre)  Temperature (°C)  \
# 0       1230.000000                   80.000000         28.000000
# 1        480.000000                   60.000000         36.000000
# 2       1250.000000                   75.000000         29.000000
# 3        450.000000                   65.000000         35.000000
# 4       1200.000000                   80.000000         27.000000
# ..              ...                         ...               ...
# 98      1230.000000                   80.000000         28.000000
# 99       400.000000                   50.000000         24.000000
# 100     1300.000000                   80.000000         40.000000
# 101      849.797980                   67.808081         32.393939
# 102      400.042676                   10.028202          5.426350
#
#      Nitrogen (N)  Phosphorus (P)  Potassium (K)      Yeild
# 0       80.000000       24.000000      20.000000  12.000000
# 1       70.000000       20.000000      18.000000   8.000000
# 2       78.000000       22.000000      19.000000  11.000000
# 3       70.000000       19.000000      18.000000   9.000000
# 4       79.000000       22.000000      19.000000  11.000000
# ..            ...             ...            ...        ...
# 98      80.000000       24.000000      20.000000  12.000000
# 99      59.000000       18.000000      15.000000   5.500000
# 100     80.000000       25.000000      22.000000  12.000000
# 101     70.737374       21.131313      18.060606   9.050505
# 102      6.677079        1.951695       1.817254   1.965902
#
# [103 rows x 7 columns]>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
x = df.drop('Yeild',axis=1)

# %%
x
# Out:
#      Rain Fall (mm)  Fertilizer(urea) (kg/acre)  Temperature (°C)  \
# 0       1230.000000                   80.000000         28.000000
# 1        480.000000                   60.000000         36.000000
# 2       1250.000000                   75.000000         29.000000
# 3        450.000000                   65.000000         35.000000
# 4       1200.000000                   80.000000         27.000000
# ..              ...                         ...               ...
# 98      1230.000000                   80.000000         28.000000
# 99       400.000000                   50.000000         24.000000
# 100     1300.000000                   80.000000         40.000000
# 101      849.797980                   67.808081         32.393939
# 102      400.042676                   10.028202          5.426350
#
#      Nitrogen (N)  Phosphorus (P)  Potassium (K)
# 0       80.000000       24.000000      20.000000
# 1       70.000000       20.000000      18.000000
# 2       78.000000       22.000000      19.000000
# 3       70.000000       19.000000      18.000000
# 4       79.000000       22.000000      19.000000
# ..            ...             ...            ...
# 98      80.000000       24.000000      20.000000
# 99      59.000000       18.000000      15.000000
# 100     80.000000       25.000000      22.000000
# 101     70.737374       21.131313      18.060606
# 102      6.677079        1.951695       1.817254
#
# [103 rows x 6 columns]

# %%
y = df.Yeild

# %%
y
# Out:
# 0      12.000000
# 1       8.000000
# 2      11.000000
# 3       9.000000
# 4      11.000000
#          ...
# 98     12.000000
# 99      5.500000
# 100    12.000000
# 101     9.050505
# 102     1.965902
# Name: Yeild, Length: 103, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=40)

# %%
x_train
# Out:
#     Rain Fall (mm)  Fertilizer(urea) (kg/acre)  Temperature (°C)  \
# 98          1230.0                        80.0              28.0
# 20           410.0                        50.0              37.0
# 76          1300.0                        80.0              28.0
# 77           400.0                        50.0              40.0
# 48          1220.0                        77.0              29.0
# ..             ...                         ...               ...
# 56          1280.0                        73.0              28.0
# 37           425.0                        60.0              39.0
# 7            425.0                        65.0              37.0
# 91           460.0                        60.0              39.0
# 70          1245.0                        77.0              27.0
#
#     Nitrogen (N)  Phosphorus (P)  Potassium (K)
# 98          80.0            24.0           20.0
# 20          59.0            19.0           15.0
# 76          80.0            24.0           20.0
# 77          60.0            18.0           15.0
# 48          75.0            22.0           19.0
# ..           ...             ...            ...
# 56          75.0            24.0           19.0
# 37          60.0            18.0           15.0
# 7           67.0            18.0           15.0
# 91          60.0            20.0           16.0
# 70          75.0            22.0           20.0
#
# [82 rows x 6 columns]

# %%
x_test
# Out:
#      Rain Fall (mm)  Fertilizer(urea) (kg/acre)  Temperature (°C)  \
# 17       410.000000                   55.000000          36.00000
# 27      1250.000000                   80.000000          28.00000
# 33       450.000000                   55.000000          38.00000
# 85       450.000000                   70.000000          36.00000
# 11       415.000000                   55.000000          38.00000
# 63       450.000000                   56.000000          40.00000
# 15       400.000000                   60.000000          39.00000
# 32      1275.000000                   76.000000          26.00000
# 47       445.000000                   60.000000          38.00000
# 40      1275.000000                   78.000000          28.00000
# 26       400.000000                   60.000000          39.00000
# 39       440.000000                   58.000000          37.00000
# 4       1200.000000                   80.000000          27.00000
# 102      400.042676                   10.028202           5.42635
# 68      1225.000000                   75.000000          29.00000
# 75       475.000000                   58.000000          39.00000
# 69       455.000000                   60.000000          38.00000
# 54      1245.000000                   78.000000          27.00000
# 86      1250.000000                   77.000000          28.00000
# 9        400.000000                   50.000000          39.00000
# 95       425.000000                   60.000000          39.00000
#
#      Nitrogen (N)  Phosphorus (P)  Potassium (K)
# 17      65.000000       21.000000      16.000000
# 27      80.000000       24.000000      20.000000
# 33      65.000000       19.000000      17.000000
# 85      72.000000       25.000000      18.000000
# 11      65.000000       19.000000      17.000000
# 63      67.000000       18.000000      15.000000
# 15      60.000000       18.000000      15.000000
# 32      75.000000       24.000000      19.000000
# 47      68.000000       22.000000      18.000000
# 40      77.000000       23.000000      21.000000
# 26      60.000000       18.000000      15.000000
# 39      66.000000       22.000000      18.000000
# 4       79.000000       22.000000      19.000000
# 102      6.677079        1.951695       1.817254
# 68      77.000000       23.000000      19.000000
# 75      68.000000       19.000000      16.000000
# 69      65.000000       20.000000      16.000000
# 54      78.000000       22.000000      19.000000
# 86      76.000000       22.000000      19.000000
# 9       60.000000       18.000000      15.000000
# 95      65.000000       19.000000      17.000000

# %%
y_train
# Out:
# 98    12.0
# 20     6.0
# 76    12.0
# 77     6.0
# 48    10.0
#       ...
# 56    11.0
# 37     6.0
# 7      7.0
# 91     7.0
# 70     9.5
# Name: Yeild, Length: 82, dtype: float64

# %%
y_test
# Out:
# 17      7.000000
# 27     12.000000
# 33      7.000000
# 85      8.000000
# 11      8.000000
# 63      7.000000
# 15      5.500000
# 32     11.000000
# 47      8.000000
# 40     11.000000
# 26      6.000000
# 39      8.000000
# 4      11.000000
# 102     1.965902
# 68     10.000000
# 75      7.500000
# 69      8.500000
# 54     10.000000
# 86     10.000000
# 9       6.000000
# 95      6.500000
# Name: Yeild, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([ 0.00061984, -0.02889604, -0.06056551,  0.10685982,  0.22768345,
#         0.32238555])

# %%
lr.intercept_
# Out:
# -5.727879910807411

# %%
y_pred = lr.predict(x_test)

# %%
y_pred
# Out:
# array([ 7.6420242 , 11.50030421,  7.41270551,  9.53690088,  7.39101105,
#         6.60394355,  5.76991405, 10.89583078,  8.59114145, 11.34771498,
#         5.76991405,  8.49268019, 10.64526536, -4.35460526, 10.6980744 ,
#         7.27914184,  7.17662241, 10.62409051, 10.38180061,  6.05887447,
#         7.19216375])

# %%
y_test
# Out:
# 17      7.000000
# 27     12.000000
# 33      7.000000
# 85      8.000000
# 11      8.000000
# 63      7.000000
# 15      5.500000
# 32     11.000000
# 47      8.000000
# 40     11.000000
# 26      6.000000
# 39      8.000000
# 4      11.000000
# 102     1.965902
# 68     10.000000
# 75      7.500000
# 69      8.500000
# 54     10.000000
# 86     10.000000
# 9       6.000000
# 95      6.500000
# Name: Yeild, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mse = mean_squared_error(y_pred,y_test)

# %%
mse
# Out:
# 2.283410497128233

# %%
mae = mean_absolute_error(y_pred,y_test)

# %%
mae
# Out:
# 0.8003123277753408

# %%
from sklearn.metrics import r2_score

# %%
r2_score = r2_score(y_pred,y_test)

# %%
r2_score
# Out:
# 0.7937946824385209

# %%
n = len(y_test)

# %%
n
# Out:
# 21

# %%
k = x_test.shape[1]

# %%
k
# Out:
# 6

# %%
adj_r2 = 1-(1-r2_score)*(n-1)/(n-k-1)

# %%
adj_r2
# Out:
# 0.7054209749121727
